# %%
#Load Env Variables

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
#Anthropic SDK

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %%
#request

message = client.messages.create(
    model = model,
    max_tokens = 1000,
    messages = [
        {
            "role" : "user",
            "content" : "what is quantum computing? Answer in one sentence"
        }
    ]
)


message = client.messages.create(
    model = model,
    max_tokens = 1000,
    messages = [
        {
            "role" : "user",
            "content" : "write another sentence"
        }
    ]
)

message.content[0].text

# %%
message.content[0].text
# Out:
# "The morning sun cast long shadows across the empty street as a lone cat picked its way carefully between puddles from last night's rain."
