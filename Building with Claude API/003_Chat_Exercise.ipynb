# %%
#Load Env Variables

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
#Anthropic SDK

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %%
def add_user_message(messages, text):
    user_message = {"role":"user", "content" : text}
    messages.append(user_message)
    
def add_assistant_message(messages, text):
    assistant_message = {"role":"assistant", "content" : text}
    messages.append(assistant_message)
    
def chat(messages):
    message = client.messages.create(
        model = model,
        max_tokens = 1000,
        messages = messages
    )
    return message.content[0].text

# %%
messages = []

while True:
    user_input = input("> ")
    print(">" , user_input)
    
    #add User message
    add_user_message(messages, user_input)
    #call the chat
    answer = chat(messages)
    #add generated message
    add_assistant_message(messages,answer)
    #print assistant message
    
    print("---")
    print(answer)
    print("---")
# Out:
# Great question! Let's work through this step by step.
#
# The goal when solving for x is to get x by itself on one side of the equation. Right now we have:
# 5x + 3 = 2
#
# What do you think we should do first to start isolating the x term? Look at what's being done to x - it's being multiplied by 5, and then 3 is being added to that result.
#
# What operation could we use to "undo" the +3?
